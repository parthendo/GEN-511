# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Pima_Indian_diabetes.csv",header = None)
data = data. drop([0], axis=0)

# %%
data[8] = data[8].replace(to_replace = 0, value = 2)  
#data.replace(to_replace = 0.0, value = np.nan) 
data
# Out:
#         0      1     2     3      4                  5                    6  \
# 1     6.0  148.0  72.0  35.0    0.0               33.6                0.627
# 2     1.0   85.0  66.0  29.0    0.0               26.6  0.35100000000000003
# 3     8.0  183.0  64.0   0.0    0.0               23.3                0.672
# 4     1.0   89.0  66.0  23.0   94.0  19.17992516305501  0.16699999999999998
# 5     0.0  137.0  40.0  35.0  168.0               43.1   2.2880000000000003
# ..    ...    ...   ...   ...    ...                ...                  ...
# 764  10.0  101.0  76.0  48.0  180.0               32.9                0.171
# 765   2.0  122.0  70.0  27.0    0.0               36.8                 0.34
# 766   5.0  121.0  72.0  23.0  112.0               26.2                0.245
# 767   1.0  126.0  60.0   0.0    0.0               30.1                0.349
# 768   1.0   93.0  70.0  31.0    0.0               30.4                0.315
#
#         7  8
# 1    50.0  1
# 2    31.0  0
# ...
